# %%
# !pip install onnxscript

# %%
from main import run_pipeline

# %%
experiments = [
        {
            "model_type": "basic",
            "validation_size": 30,
            "test_size": 30,
            "split_seed": 42,
            "retrain_model": True,
            "regenerate_masks": True,
            "metrics_json_name": "evaluation_metrics_basic.json",
        },
        {
            "model_type": "basic",
            "validation_size": 30,
            "test_size": 30,
            "split_seed": 42,
            "retrain_model": True,
            "regenerate_masks": False,
            "metrics_json_name": "evaluation_metrics_basic_8.json",
            "basic_stardist_n_rays": 8,
            "basic_stardist_model_name": "stardist_rebar_8",
        },
        {
            "model_type": "yolo",
            "validation_size": 30,
            "test_size": 30,
            "split_seed": 42,
            "retrain_model": True,
            "regenerate_masks": False,
            "metrics_json_name": "evaluation_metrics_yolo_stardist.json",
            "yolo_epochs": 10,
            "onnx_export_path": "export/yolo_stardist.onnx",
        },
        {
            "model_type": "yolo_bbox",
            "validation_size": 30,
            "test_size": 30,
            "split_seed": 42,
            "retrain_model": True,
            "regenerate_masks": False,
            "metrics_json_name": "evaluation_metrics_yolo_bbox.json",
            "yolo_model_name": "yolo11n.pt",
            "yolo_epochs": 10,
        },
        {
            "model_type": "yolo_seg",
            "validation_size": 30,
            "test_size": 30,
            "split_seed": 42,
            "retrain_model": True,
            "regenerate_masks": False,
            "metrics_json_name": "evaluation_metrics_yolo_seg.json",
            "yolo_model_name": "yolo11n.pt",
            "yolo_epochs": 10,
            "onnx_export_path": "export/yolo_seg.onnx",
        },    
    ]

# %%
run_pipeline(**experiments[2])

# %%
# run_pipeline(**experiments[2])

# %%
# run_pipeline(**experiments[1])

# %%
# run_pipeline(**experiments[0])
